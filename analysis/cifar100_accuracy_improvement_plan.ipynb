# %%
model_path = os.path.join(doc_path,"239-stage-1_1_3_6_3-ratio-1.0_1.0_0.625_0.375_0.75-op-repvgg_repvgg_vgg_vgg_repvgg-pool-False_True_False_True_False_False-pool_type-None_avgpool_None_avgpool_None_None-cifar100.yaml","best_ckpt.pth")
os.path.exists(model_path)
# Out:
# False

# %%
import os
import matplotlib.pyplot as plt
import tqdm
import torch
import numpy as np
doc_path = "/home/qhy/Reserach/AICAS/log/cifar100"
pathlist = os.listdir(doc_path)
acc = []
acc_map = np.zeros(390)
for p in tqdm.tqdm(pathlist):
    model_path = os.path.join(doc_path,p,"best_ckpt.pth")
    # print(p)
    if os.path.exists(model_path) == False:
        os.remove(os.path.join("/home/qhy/Reserach/AICAS/config/cifar100",p))
        print(p)
    # acc.append(model_param['max_accuracy'])
    if len(p.split("-")[0]) < 5 and int(p.split("-")[0])>=220:
        model_path = os.path.join(doc_path,p,"best_ckpt.pth")
        model_param = torch.load(model_path)
        acc_map[int(p.split("-")[0])] = model_param['max_accuracy']
# plt.scatter(range(len(acc)),acc)
# plt.ylim(50,75)
# plt.show()
plt.scatter(range(250,390),acc_map[250:390])
plt.ylim(65,75)
plt.show()
# Out:
# 100%|██████████| 387/387 [11:49<00:00,  1.83s/it]

# %%
plt.scatter(range(310,390),acc_map[310:390])
plt.ylim(60,71)
plt.show()

# %%
acc_map[230]
acc_map[234]
acc_map[276]
acc_map[311]
acc_map[329]
# Out:
# 69.12

# %%
model_path = os.path.join("/home/qhy/Reserach/AICAS/log/cifar100/benchmark-vgg13-stage-2_2_2_2_2-ratio-1.0_1.0_1.0_1.0_1.0-op-vgg_vgg_vgg_vgg_vgg-max-False_True_True_True_True-cifar100","best_ckpt.pth")
model_param = torch.load(model_path)
model_param['max_accuracy']
# Out:
# 70.68

# %%
acc_map[219]
# Out:
# 62.01

# %%
print(max(acc_map[160:]))
print(max(acc_map[160:]))
# print((acc_map[15:18]))
# Out:
# 68.72
# 68.72

# %%
acc_map[16]
# Out:
# 67.35

# %%
plt.scatter(range(120),acc_map)
plt.ylim(50,75)
plt.show()

# %% [markdown]
# 100-109 cifar100 在vgg上进行搜索
# 110-119 改为vgg+repvgg搜索 修改超参，lr=0.5
