# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
h = []
w = []
for i in os.listdir("/home/qhy/data/Face Mask Dataset/Train/WithMask") :
    a = Image.open("/home/qhy/data/Face Mask Dataset/Train/WithMask/"+i)
    h.append(a.size[0])
    w.append(a.size[1])
plt.scatter(h,w)

# %%
# Out:
# (700, 700)
